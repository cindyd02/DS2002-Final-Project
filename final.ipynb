# %%
import pandas as pd

vaccinations = pd.read_csv('country_vaccinations.csv')
records = pd.read_csv('country_wise_latest.csv')

print('Vaccinations: \n')
print(vaccinations.head())

print('Records: \n')
print(records.head())
# Out:
# Vaccinations:
#
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
# deescribing vaccinations dataframe
vaccinations.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        4.360700e+04       4.129400e+04             3.880200e+04
# mean         4.592964e+07       1.770508e+07             1.413830e+07
# std          2.246004e+08       7.078731e+07             5.713920e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          5.264100e+05       3.494642e+05             2.439622e+05
# 50%          3.590096e+06       2.187310e+06             1.722140e+06
# 75%          1.701230e+07       9.152520e+06             7.559870e+06
# max          3.263129e+09       1.275541e+09             1.240777e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            3.536200e+04        8.621300e+04
# mean             2.705996e+05        1.313055e+05
# std              1.212427e+06        7.682388e+05
# min              0.000000e+00        0.000000e+00
# 25%              4.668000e+03        9.000000e+02
# ...

# %%
# describing records dataframe: 
records.describe()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
# ...

# %% [markdown]
# ## Rationale for Dataset Selection
#
# 1. **country_vaccinations.csv**: This dataset provides information on COVID-19 vaccinations by country, allowing us to analyze vaccination progress globally.
#
# 2. **country_wise_latest.csv**: This dataset offers country-wise COVID-19 statistics, enabling us to compare infection rates, deaths, and recoveries across nations.
#
# These datasets together will provide insights into the relationship between vaccination efforts and COVID-19 outcomes across different countries.

# %% [markdown]
# ## ETL Setup

# %%
# filter the vaccinations dataset for US data
us_vaccinations = vaccinations[(vaccinations['country'] == 'United States') | (vaccinations['iso_code'] == 'USA')]

print('\nFiltered Vaccinations Data for United States: \n')
us_vaccinations.head()
# Out:
# Filtered Vaccinations Data for United States:
#              country iso_code        date  total_vaccinations  \
# 82360  United States      USA  2020-12-13             30288.0
# 82361  United States      USA  2020-12-14             34867.0
# 82362  United States      USA  2020-12-15             84638.0
# 82363  United States      USA  2020-12-16            244549.0
# 82364  United States      USA  2020-12-17            517161.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 82360            25125.0                   5897.0                     NaN
# 82361            29543.0                   6017.0                  4579.0
# 82362            76984.0                   6281.0                 49771.0
# 82363           231496.0                   6757.0                159911.0
# 82364           496980.0                   7507.0                272612.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# ...

# %%
# checking for missing values
print("\nMissing values in Vaccinations dataset:")
print(us_vaccinations.isnull().sum())

print("\nMissing values in Records dataset:")
print(records.isnull().sum())
# Out:
# Missing values in Vaccinations dataset:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 1
# daily_vaccinations                     1
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         1
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64
#
# Missing values in Records dataset:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# ...

# %%
# remove rows with missing values
us_vaccinations_cleaned = us_vaccinations.dropna()

# check for missing values in the cleaned dataset
print("\nMissing values in cleaned US Vaccinations dataset:")
print(us_vaccinations_cleaned.isnull().sum())

print(f"\nRows before cleaning: {len(us_vaccinations)}")
print(f"Rows after cleaning: {len(us_vaccinations_cleaned)}")
# Out:
# Missing values in cleaned US Vaccinations dataset:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64
#
# Rows before cleaning: 471
# Rows after cleaning: 470
